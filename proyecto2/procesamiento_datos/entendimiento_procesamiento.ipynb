# %% [markdown]
# ### Importe de librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Carga de datos

# %%
# Cargar datos desde mineriaInfo.json
df_mineria = pd.read_json('../Datos/mineriaInfo.json')
df_mineria.sample(5)
# Out:
#        codigo_dane municipio_productor departamento   recurso_natural  \
# 4344          5604            Remedios    Antioquia               ORO
# 37211        63690             Salento      Quindio               ORO
# 21406        23580   Puerto Libertador      Cordoba            CARBON
# 37364        66075                Aipe        Huila            GRAVAS
# 12222        15516               Paipa       Boyaca  GRAVA DE CANTERA
#
#       nombre_del_proyecto  a_o_produccion    trimestre   unidad_medida  \
# 4344          PRODUCTORES            2015  Trimestre 3          GRAMOS
# 37211         PRODUCTORES            2015  Trimestre 2          GRAMOS
# 21406         PRODUCTORES            2012  Trimestre 2       TONELADAS
# 37364         PRODUCTORES            2021  Trimestre 2  METROS CUBICOS
# 12222         PRODUCTORES            2014  Trimestre 4  METROS CUBICOS
#
#       tipo_contraprestacion  valor_contraprestacion  cantidad_producci_n
# 4344                REGALIA             204172438.0              65048.0
# 37211               REGALIA               4805541.0               1560.0
# 21406               REGALIA             181947480.0              33712.0
# 37364               REGALIA               1051562.0               4965.0
# 12222               REGALIA                225266.0               1931.0

# %%
# Read xlsx file
df_conflicto = pd.read_excel('../Datos/Conflicto Armado.xlsx')
df_conflicto.sample(5)
# Out:
#         Código Departamento Departamento  Código Entidad      Entidad  \
# 197550                 15.0       Boyacá         15248.0    El Espino
# 177063                 13.0      Bolívar         13062.0  Arroyohondo
# 45045                  63.0      Quindío         63190.0     Circasia
# 250760                 15.0       Boyacá         15215.0     Corrales
# 280208                 15.0       Boyacá         15403.0     La Uvita
#
#                                      Dimensión  \
# 197550  Conflicto armado y seguridad ciudadana
# 177063  Conflicto armado y seguridad ciudadana
# 45045   Conflicto armado y seguridad ciudadana
# 250760  Conflicto armado y seguridad ciudadana
# 280208  Conflicto armado y seguridad ciudadana
#
#                                         Subcategoría  \
# 197550   Homicidios por agresor y sexo de la víctima
# 177063   Homicidios por agresor y sexo de la víctima
# 45045                               Conflicto armado
# 250760   Homicidios por agresor y sexo de la víctima
# 280208  Violencia de pareja según sexo de la víctima
#
#                                                 Indicador Dato Numérico  \
# 197550  Homicidio de hombres por:  Personal de custodi...           NaN
# 177063      Homicidio de hombres por:  Delincuencia común           NaN
# 45045                      Número de personas desplazadas          0,00
# 250760  Homicidio de mujeres por:  Delincuencia organi...           NaN
# 280208              Violencia de pareja -  Total de casos           NaN
#
#        Dato Cualitativo     Año   Mes  \
# 197550              NaN  2016.0  12.0
# 177063              NaN  2016.0  12.0
# 45045               NaN  1986.0  12.0
# 250760              NaN  2015.0  12.0
# 280208              NaN  2014.0  12.0
#
#                                                    Fuente Unidad de Medida
# 197550  Instituto Nacional de Medicina Legal y Ciencia...         Personas
# 177063  Instituto Nacional de Medicina Legal y Ciencia...         Personas
# 45045   Unidad para la Atención y Reparación Integral ...         Personas
# 250760  Instituto Nacional de Medicina Legal y Ciencia...         Personas
# 280208  Instituto Nacional de Medicina Legal y Ciencia...         Personas

# %%
# Read xlsx file
df_demografia = pd.read_excel('../Datos/Demografía Y Poblacion.xlsx')
df_demografia.sample(5)
# Out:
#         Código Departamento        Departamento  Código Entidad  \
# 693109                 15.0              Boyacá         15248.0
# 437586                 15.0              Boyacá         15236.0
# 128421                 19.0               Cauca         19300.0
# 362171                 54.0  Norte de Santander         54553.0
# 458341                 19.0               Cauca         19256.0
#
#                  Entidad               Dimensión  \
# 693109         El Espino  Demografía y población
# 437586            Chivor  Demografía y población
# 128421          Guachené  Demografía y población
# 362171  Puerto Santander  Demografía y población
# 458341          El Tambo  Demografía y población
#
#                                            Subcategoría  \
# 693109  Población total por grupos quinquenales de edad
# 437586                             Población de mujeres
# 128421                             Población de hombres
# 362171                             Población de mujeres
# 458341                             Población de mujeres
#
#                                                 Indicador Dato Numérico  \
# 693109  Porcentaje de población entre los 5 y 9 años, ...          6,80
# 437586       Porcentaje de población de mujeres de  65-69          1,96
# 128421       Porcentaje de población de hombres de  05-09          3,75
# 362171       Porcentaje de población de mujeres de  10-14          4,68
# 458341     Porcentaje de población de mujeres de 80 o más          1,80
#
#         Dato Cualitativo     Año   Mes  \
# 693109               NaN  2018.0  12.0
# 437586               NaN  2019.0  12.0
# 128421               NaN  2023.0  12.0
# 362171               NaN  2019.0  12.0
# 458341               NaN  2020.0  12.0
#
#                                                Fuente  \
# 693109  DANE - Censo Nacional de Población y Vivienda
# 437586  DANE - Censo Nacional de Población y Vivienda
# 128421  DANE - Censo Nacional de Población y Vivienda
# 362171  DANE - Censo Nacional de Población y Vivienda
# 458341  DANE - Censo Nacional de Población y Vivienda
#
#                                        Unidad de Medida
# 693109                                       Porcentaje
# 437586  Porcentaje (el valor está multiplicado por 100)
# 128421  Porcentaje (el valor está multiplicado por 100)
# 362171  Porcentaje (el valor está multiplicado por 100)
# 458341  Porcentaje (el valor está multiplicado por 100)

# %%
# Read xlsx file
df_desempleo = pd.read_excel('../Datos/Medicion de desempleo municipal.xlsx')
df_desempleo.sample(5)
# Out:
#         Código Departamento Departamento  Código Entidad           Entidad  \
# 109131                 20.0        Cesar         20228.0          Curumaní
# 49450                  68.0    Santander         68655.0  Sabana de Torres
# 139836                 17.0       Caldas         17013.0           Aguadas
# 106782                 15.0       Boyacá         15832.0          Tununguá
# 57657                  15.0       Boyacá         15600.0           Ráquira
#
#                               Dimensión              Subcategoría  \
# 109131  Medición de desempeño municipal  Componente de resultados
# 49450   Medición de desempeño municipal               Resumen MDM
# 139836  Medición de desempeño municipal  Componente de resultados
# 106782  Medición de desempeño municipal  Componente de resultados
# 57657   Medición de desempeño municipal     Componente de gestión
#
#                                     Indicador Dato Numérico Dato Cualitativo  \
# 109131                                  Salud         89,14              NaN
# 49450                          MDM - Posición        214,00              NaN
# 139836  Promedio de seguridad por grupo de DI         90,83              NaN
# 106782                                  Salud         84,31              NaN
# 57657                Movilización de recursos         12,06              NaN
#
#            Año   Mes     Fuente Unidad de Medida
# 109131  2019.0  12.0  DNP - SPT           Puntos
# 49450   2020.0  12.0  DNP - SPT           Número
# 139836  2017.0  10.0  DNP - SPT  Puntos promedio
# 106782  2017.0  10.0  DNP - SPT           Puntos
# 57657   2017.0  10.0  DNP - SPT           Puntos

# %%
# Read xlsx file
df_vivienda = pd.read_excel('../Datos/TerriData_Dim3_viviendaServiciosPublicos.xlsx')
df_vivienda.sample(5)
# Out:
#         Código Departamento     Departamento  Código Entidad      Entidad  \
# 148029                 76.0  Valle del Cauca         76895.0       Zarzal
# 191528                 52.0           Nariño         52320.0  Guaitarilla
# 132128                 15.0           Boyacá         15187.0      Chivatá
# 133350                 41.0            Huila         41026.0     Altamira
# 160844                 73.0           Tolima         73547.0      Piedras
#
#                                      Dimensión  \
# 148029  Vivienda y acceso a servicios públicos
# 191528  Vivienda y acceso a servicios públicos
# 132128  Vivienda y acceso a servicios públicos
# 133350  Vivienda y acceso a servicios públicos
# 160844  Vivienda y acceso a servicios públicos
#
#                                   Subcategoría  \
# 148029  Vivienda y acceso a servicios públicos
# 191528  Vivienda y acceso a servicios públicos
# 132128  Vivienda y acceso a servicios públicos
# 133350  Vivienda y acceso a servicios públicos
# 160844  Vivienda y acceso a servicios públicos
#
#                                        Indicador Dato Numérico  \
# 148029   Cobertura de alcantarillado rural (REC)          0,00
# 191528             Cobertura de aseo rural (REC)        100,00
# 132128  Cobertura de alcantarillado urbana (REC)        100,00
# 133350  Cobertura de alcantarillado urbana (REC)         92,59
# 160844                   Cobertura de aseo (REC)          5,96
#
#         Dato Cualitativo     Año   Mes  \
# 148029               NaN  2015.0  12.0
# 191528              10.0  2010.0  12.0
# 132128               NaN  2013.0  12.0
# 133350               NaN  2014.0  12.0
# 160844               NaN  2009.0  12.0
#
#                                                    Fuente Unidad de Medida
# 148029  Superintendencia de Servicios Públicos Domicil...       Porcentaje
# 191528  Superintendencia de Servicios Públicos Domicil...       Porcentaje
# 132128  Superintendencia de Servicios Públicos Domicil...       Porcentaje
# 133350  Superintendencia de Servicios Públicos Domicil...       Porcentaje
# 160844  Superintendencia de Servicios Públicos Domicil...       Porcentaje

# %%
# Read xlsx file
df_educacion = pd.read_excel('../Datos/TerriData_Dim4_Educacion.xlsx')
df_educacion.sample(5)
# Out:
#         Código Departamento        Departamento  Código Entidad  \
# 215650                  8.0           Atlántico          8549.0
# 244610                 20.0               Cesar         20045.0
# 68656                  27.0               Chocó         27810.0
# 155714                 50.0                Meta         50001.0
# 276593                 54.0  Norte de Santander         54720.0
#
#                    Entidad  Dimensión           Subcategoría  \
# 215650               Piojó  Educación  Acceso a la educación
# 244610            Becerril  Educación   Permanencia y rezago
# 68656   Unión Panamericana  Educación  Acceso a la educación
# 155714       Villavicencio  Educación  Acceso a la educación
# 276593           Sardinata  Educación                Calidad
#
#                                                 Indicador Dato Numérico  \
# 215650                Cobertura neta en educación - Total         67,07
# 244610  Tasa de repitencia del sector oficial en educa...           NaN
# 68656                  Cobertura bruta en educación media         67,44
# 155714             Cobertura neta en educación secundaria         79,15
# 276593    Puntaje promedio Pruebas Saber 11 - Matemáticas         50,00
#
#         Dato Cualitativo     Año   Mes                            Fuente  \
# 215650               NaN  2020.0  12.0  Ministerio de Educación Nacional
# 244610               NaN  2008.0  12.0  Ministerio de Educación Nacional
# 68656                NaN  2017.0  12.0  Ministerio de Educación Nacional
# 155714               NaN  2015.0  12.0  Ministerio de Educación Nacional
# 276593               NaN  2019.0  11.0                             ICFES
#
#                                        Unidad de Medida
# 215650  Porcentaje (el valor está multiplicado por 100)
# 244610  Porcentaje (el valor está multiplicado por 100)
# 68656   Porcentaje (el valor está multiplicado por 100)
# 155714  Porcentaje (el valor está multiplicado por 100)
# 276593                                           Puntos

# %%
# Read xlsx file
df_salud = pd.read_excel('../Datos/TerriData_Dim5_salud.xlsx')
df_salud.sample(5)
# Out:
#         Código Departamento     Departamento  Código Entidad     Entidad  \
# 291837                 41.0            Huila         41801.0      Teruel
# 302431                 50.0             Meta         50223.0    Cubarral
# 467347                 76.0  Valle del Cauca         76122.0  Caicedonia
# 286404                 41.0            Huila         41503.0     Oporapa
# 345799                 76.0  Valle del Cauca         76670.0   San Pedro
#
#        Dimensión        Subcategoría  \
# 291837     Salud  Tasas y coberturas
# 302431     Salud  Tasas y coberturas
# 467347     Salud  Tasas y coberturas
# 286404     Salud  Tasas y coberturas
# 345799     Salud  Tasas y coberturas
#
#                                                Indicador Dato Numérico  \
# 291837  Tasa de mortalidad infantil en menores de 5 años         40,27
# 302431  Tasa de mortalidad infantil en menores de 5 años         12,82
# 467347                    Tasa de negligencia y abandono         55,15
# 286404  Tasa de mortalidad infantil en menores de 5 años         17,54
# 345799  Mortalidad por desnutrición en menores de 5 años           NaN
#
#        Dato Cualitativo     Año   Mes  \
# 291837              NaN  2011.0  12.0
# 302431              NaN  2020.0  12.0
# 467347              NaN  2018.0  12.0
# 286404              NaN  2006.0  12.0
# 345799              NaN  2010.0  12.0
#
#                                                    Fuente  \
# 291837                                Ministerio de Salud
# 302431                                Ministerio de Salud
# 467347  Fondo de Población de las Naciones Unidas - UN...
# 286404                                Ministerio de Salud
# 345799                                Ministerio de Salud
#
#                                   Unidad de Medida
# 291837          Casos por cada 1.000 nacidos vivos
# 302431          Casos por cada 1.000 nacidos vivos
# 467347  Casos de abandono por cada 100.000 mujeres
# 286404          Casos por cada 1.000 nacidos vivos
# 345799          Casos por cada 1.000 nacidos vivos

# %%
# Read xlsx file
df_pobreza = pd.read_excel('../Datos/TerriData_Dim14_pobreza.xlsx')
df_pobreza.sample(5)
# Out:
#        Código Departamento Departamento  Código Entidad        Entidad  \
# 9611                   5.0    Antioquia          5893.0          Yondó
# 8772                  85.0     Casanare         85440.0     Villanueva
# 18164                 17.0       Caldas         17000.0         Caldas
# 16872                 44.0   La Guajira         44000.0     La Guajira
# 13296                 86.0     Putumayo         86755.0  San Francisco
#
#       Dimensión                                       Subcategoría  \
# 9611    Pobreza                             Indicadores de pobreza
# 8772    Pobreza                             Indicadores de pobreza
# 18164   Pobreza  Incidencia de pobreza monetaria según sexo del...
# 16872   Pobreza         Incidencia de pobreza monetaria según sexo
# 13296   Pobreza                             Indicadores de pobreza
#
#                                                Indicador Dato Numérico  \
# 9611                                         IPM - Rural         52,70
# 8772                                         IPM - Rural         32,30
# 18164  Incidencia de pobreza monetaria  en hogares co...         29,92
# 16872         Incidencia de pobreza monetaria en mujeres         55,51
# 13296  Población en condición de miseria en el área u...          1,03
#
#        Dato Cualitativo     Año   Mes  \
# 9611                NaN  2018.0  12.0
# 8772                NaN  2018.0  12.0
# 18164               NaN  2013.0  12.0
# 16872               NaN  2013.0  12.0
# 13296               NaN  2018.0  12.0
#
#                                                   Fuente  \
# 9611                                                DANE
# 8772                                                DANE
# 18164                               DNP a partir de DANE
# 16872                               DNP a partir de DANE
# 13296  Departamento Administrativo Nacional de Estadí...
#
#                                       Unidad de Medida
# 9611   Porcentaje (el valor está multiplicado por 100)
# 8772   Porcentaje (el valor está multiplicado por 100)
# 18164  Porcentaje (el valor está multiplicado por 100)
# 16872  Porcentaje (el valor está multiplicado por 100)
# 13296                              Puntos porcentuales

# %% [markdown]
# # Procesamiento y limpieza de datos

# %% [markdown]
# ### Minería

# %%
df_mineria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45215 entries, 0 to 45214
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   codigo_dane             45215 non-null  int64
#  1   municipio_productor     45215 non-null  object
#  2   departamento            45215 non-null  object
#  3   recurso_natural         45215 non-null  object
#  4   nombre_del_proyecto     45215 non-null  object
#  5   a_o_produccion          45215 non-null  int64
#  6   trimestre               45215 non-null  object
#  7   unidad_medida           45215 non-null  object
#  8   tipo_contraprestacion   45215 non-null  object
#  9   valor_contraprestacion  45155 non-null  float64
#  10  cantidad_producci_n     45214 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 3.8+ MB

# %%
# Replace null values in cantidad_producci_n column with its mean
df_mineria['cantidad_producci_n'].fillna(df_mineria['cantidad_producci_n'].mean(), inplace=True)

# Delete rows with null values
df_mineria.dropna(inplace=True)

# %%
# Remove word 'Trimestre ' from column 'trimestre'
df_mineria['trimestre'] = df_mineria['trimestre'].str.replace('Trimestre ', '')

# Convert column 'trimestre' to int
df_mineria['trimestre'] = df_mineria['trimestre'].astype(int)

# %%
# Graph histogram of 'valor_contraprestacion' and 'cantidad_producci_n'
df_mineria[['valor_contraprestacion', 'cantidad_producci_n']].hist(figsize=(18, 5))
# Out:
# array([[<AxesSubplot:title={'center':'valor_contraprestacion'}>,
#         <AxesSubplot:title={'center':'cantidad_producci_n'}>]],
#       dtype=object)

# %%
# Visualización de distribuciones de las columnas con sns
fig, ax = plt.subplots(3, 2, figsize=(15, 10))
sns.histplot(df_mineria['departamento'], ax=ax[0, 0])
sns.histplot(df_mineria['recurso_natural'], ax=ax[0, 1])
sns.histplot(df_mineria['a_o_produccion'], ax=ax[1, 0])
sns.histplot(df_mineria['trimestre'], ax=ax[1, 1])
sns.histplot(df_mineria['unidad_medida'], ax=ax[2, 0])
sns.histplot(df_mineria['tipo_contraprestacion'], ax=ax[2, 1])
# sns.histplot(df_mineria['valor_contraprestacion'], ax=ax[2, 0], kde=True)
# sns.histplot(df_mineria['cantidad_producci_n'], ax=ax[2, 1], kde=True)
plt.show()
